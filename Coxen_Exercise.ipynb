# %% [markdown]
# # Chris Coxen RTI Exercise

# %%
import os
import json
import pandas as pd
import numpy as np  
import matplotlib as plt
import string
import nltk
import random
import pyLDAvis
import pyLDAvis.sklearn
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import word_tokenize, pos_tag
from nltk.corpus import wordnet
from nltk import FreqDist
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.manifold import MDS
from sklearn.cluster import KMeans

# %% [markdown]
# ## Task 1: Read in the data and create a new data frame from the json files

# %%
# Set the working directory to where all of the json data are stored
os.chdir('G:/My Drive/RTI/data/json')

# Create empty lists for each element of the json that we will fill with the loop below
event_ids = []
narratives = []
probable_causes = []

# Loop through each json file in the directory that contains all of the jsons
for file in os.listdir('G:/My Drive/RTI/data/json'):
    # Open each json file
    opened_json = open(file)           
    # Load it 
    loaded_json = json.load(opened_json)
    # Loop through each element of the loaded json and append that information to our three storage lists event_ids, narratives, probable_causes
    for i in range(len(loaded_json['data'])):
        event_id = loaded_json['data'][i]['EventId']
        narrative = loaded_json['data'][i]['narrative']
        probable_cause = loaded_json['data'][i]['probable_cause']
        event_ids.append(event_id)
        narratives.append(narrative)
        probable_causes.append(probable_cause)

# Zip all of the lists together into one list so we can pass it to a new dataframe
zipped_lists = list(zip(event_ids, narratives, probable_causes))

# Create a dataframe of all of our narrative information and name the columns appropriately 
narratives = pd.DataFrame(zipped_lists, columns = ['EventId', 'Narrative', 'ProbableCause'])

# %% [markdown]
# ## Join the narratives with the aviation metadata

# %%
# Read in the aviation metadata csv
# Set the working directory to where all of the data are stored 
os.chdir('G:/My Drive/RTI/data/csv')

# Read in the aviation CSV
aviation = pd.read_csv('AviationData.csv')

# Join the aviation dataframe with all_narratives that we created above. Now we have one dataframe with all of our data. 
aviation_narratives = pd.merge(aviation, narratives, on = 'EventId', how = 'inner')

# Check on how many narratives we are missing
(aviation_narratives['Narrative'].values == '').sum() # 231 total

# Not many. Let's delete the rows that are missing a narrative. We still have a large sample to work from
aviation_narratives = aviation_narratives[aviation_narratives.Narrative != '']

# %% [markdown]
# ## Task 2: Exploratory Data Analysis / Descriptive Statistics

# %%
# How are the data structured?
aviation_narratives.info()

# Convert the date column to datetime type
aviation_narratives['EventDate'] = pd.to_datetime(aviation_narratives['EventDate'])

# Pull basic descriptive statistics for our integer data (ignore the Lat / Long)
descriptive_stats = aviation_narratives.describe()
print(descriptive_stats)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77026 entries, 1 to 77256
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EventId               77026 non-null  object
#  1   InvestigationType     77026 non-null  object
#  2   AccidentNumber        77026 non-null  object
#  3   EventDate             77023 non-null  object
#  4   Location              76945 non-null  object
#  5   Country               76517 non-null  object
#  6   Latitude              23722 non-null  float64
#  7   Longitude             23713 non-null  float64
#  8   AirportCode           43300 non-null  object
#  9   AirportName           46027 non-null  object
#  10  InjurySeverity        77021 non-null  object
#  11  AircraftDamage        74747 non-null  object
#  12  AircraftCategory      16496 non-null  object
#  13  RegistrationNumber    74271 non-null  object
#  14  Make                  76938 non-null  object
#  15  Model                 76909 non-null  object
#  16  AmateurBuilt          76473 non-null  object
#  17  NumberOfEngines       73211 non-null  float64
#  18  EngineType            73921 non-null  object
#  19  FARDescription        16640 non-null  object
#  20  Schedule              11366 non-null  object
#  21  PurposeOfFlight       73533 non-null  object
#  22  AirCarrier            3812 non-null   object
#  23  TotalFatalInjuries    55697 non-null  float64
#  24  TotalSeriousInjuries  53658 non-null  float64
#  25  TotalMinorInjuries    54641 non-null  float64
#  26  TotalUninjured        65752 non-null  float64
#  27  WeatherCondition      75140 non-null  object
#  28  BroadPhaseOfFlight    70917 non-null  object
#  29  ReportStatus          77026 non-null  object
#  30  PublicationDate       63965 non-null  object
#  31  Narrative             77026 non-null  object
#  32  ProbableCause         77026 non-null  object
# dtypes: float64(7), object(26)
# memory usage: 20.0+ MB
#            Latitude     Longitude  NumberOfEngines  TotalFatalInjuries  \
# count  23722.000000  23713.000000     73211.000000        55697.000000
# mean      37.742739    -93.805724         1.149254            0.789253
# std       12.028630     39.510206         0.463209            6.092284
# min      -78.016945   -193.216667         0.000000            0.000000
# 25%       33.413334   -115.134444         1.000000            0.000000
# 50%       38.191666    -94.657222         1.000000            0.000000
# 75%       42.572917    -81.759444         1.000000            1.000000
# max       89.218056    177.557778        24.000000          349.000000
#
#        TotalSeriousInjuries  TotalMinorInjuries  TotalUninjured
# count          53658.000000        54641.000000    65752.000000
# mean               0.309907            0.492634        5.711248
# std                1.369148            2.781946       29.029928
# min                0.000000            0.000000        0.000000
# 25%                0.000000            0.000000        0.000000
# 50%                0.000000            0.000000        1.000000
# 75%                0.000000            1.000000        2.000000
# max              111.000000          380.000000      699.000000

# %%
# Pull basic stats for the categorical data of interest

# Aircraft Damage
aviation_narratives['AircraftDamage'].describe()
aviation_narratives['AircraftDamage'].value_counts()
# Out:
# Substantial    55323
# Destroyed      16977
# Minor           2447
# Name: AircraftDamage, dtype: int64

# %%
# Aircraft Category
aviation_narratives['AircraftCategory'].describe()
aviation_narratives['AircraftCategory'].value_counts()
# Out:
# Airplane             14190
# Helicopter            1771
# Glider                 261
# Balloon                120
# Gyrocraft               62
# Unknown                 40
# Weight-Shift            20
# Ultralight              18
# Powered Parachute       10
# Powered-Lift             2
# Rocket                   1
# Blimp                    1
# Name: AircraftCategory, dtype: int64

# %%
# Aircraft Make - there are multple cases used for these in the original csv (ie CESSNA and Cessna) so we'll make this column all lowercase first
aviation_narratives['Make'] = aviation['Make'].str.lower()
aviation_narratives['Make'].describe()
aviation_narratives['Make'].value_counts()
# Out:
# cessna            24275
# piper             13241
# beech              4770
# bell               2395
# boeing             2055
#                   ...
# dutton                1
# brook                 1
# calstar 1             1
# vance renegade        1
# sons mustang          1
# Name: Make, Length: 6431, dtype: int64

# %%
# Aircraft Model
aviation_narratives['Model'].describe()
aviation_narratives['Model'].value_counts()
# Out:
# 152                   2247
# 172                   1159
# 172N                  1117
# PA-28-140              900
# 172M                   769
#                       ...
# SR-10E                   1
# J4/E                     1
# SR-8E                    1
# Kitfox 6                 1
# WCS-222 (BELL 47G)       1
# Name: Model, Length: 10996, dtype: int64

# %%
# Amateur Built
aviation_narratives['AmateurBuilt'].describe()
aviation_narratives['AmateurBuilt'].value_counts()
# Out:
# No     69080
# Yes     7393
# Name: AmateurBuilt, dtype: int64

# %%
# Number of Engines
aviation_narratives['NumberOfEngines'].describe()
aviation_narratives['NumberOfEngines'].value_counts()
# Out:
# 1.0     61361
# 2.0      9843
# 0.0      1124
# 3.0       475
# 4.0       406
# 24.0        1
# 18.0        1
# Name: NumberOfEngines, dtype: int64

# %%
# Engine Type
aviation_narratives['EngineType'].describe()
aviation_narratives['EngineType'].value_counts()
# Out:
# Reciprocating       62915
# Turbo Shaft          3199
# Turbo Prop           2931
# Turbo Fan            2142
# Unknown              2053
# Turbo Jet             666
# None                    5
# TF, TJ                  3
# REC, TJ, TJ             2
# Hybrid Rocket           1
# Electric                1
# REC, TJ, REC, TJ        1
# TF, TJ, TJ              1
# TJ, REC, REC, TJ        1
# Name: EngineType, dtype: int64

# %%
# Purpose of Flight
aviation_narratives['PurposeOfFlight'].describe()
aviation_narratives['PurposeOfFlight'].value_counts()
# Out:
# Personal                     43287
# Instructional                 9258
# Unknown                       6753
# Aerial Application            4281
# Business                      3825
# Positioning                   1485
# Other Work Use                1092
# Ferry                          767
# Public Use                     700
# Aerial Observation             643
# Executive/Corporate            509
# Flight Test                    292
# Air Race/Show                  133
# Skydiving                      106
# Public Aircraft - Federal       83
# Banner Tow                      77
# External Load                   75
# Public Aircraft - State         51
# Public Aircraft - Local         49
# Glider Tow                      40
# Fire Fighting                   19
# Air Drop                         8
# Name: PurposeOfFlight, dtype: int64

# %%
# Air Carrier
aviation_narratives['AirCarrier'].describe()
aviation_narratives['AirCarrier'].value_counts()
# Out:
# UNITED AIRLINES                   49
# AMERICAN AIRLINES                 41
# CONTINENTAL AIRLINES              25
# USAIR                             24
# DELTA AIR LINES INC               23
#                                   ..
# (DBA: TANANA AIR SERVICE)          1
# SUNJET AVIATION INC                1
# ALLEGHENY AIRLINES INC.            1
# FEDEX                              1
# ROCKY MOUNTAIN HELICOPTERS, IN     1
# Name: AirCarrier, Length: 2807, dtype: int64

# %%
# Weather Conditions
aviation_narratives['WeatherCondition'].describe()
aviation_narratives['WeatherCondition'].value_counts()
# Out:
# VMC    68647
# IMC     5571
# UNK      922
# Name: WeatherCondition, dtype: int64

# %%
# Broad Phase of Flight
aviation_narratives['BroadPhaseOfFlight'].describe()
aviation_narratives['BroadPhaseOfFlight'].value_counts()
# Out:
# LANDING        18521
# TAKEOFF        14724
# CRUISE         10577
# MANEUVERING     9485
# APPROACH        7494
# TAXI            2258
# CLIMB           2223
# DESCENT         2144
# GO-AROUND       1568
# STANDING        1162
# UNKNOWN          614
# OTHER            147
# Name: BroadPhaseOfFlight, dtype: int64

# %% [markdown]
# ## Start of text processing

# %%
# Examine some of the narratives - can run as many times as you would like to get a sample of narratives
random_row = random.randint(0, len(aviation_narratives))
aviation_narratives.at[random_row, 'Narrative']
# Out:
# 'NTSB investigators used data provided by various entities, including, but not limited to, the Federal Aviation Administration and/or the operator and did not travel in support of this investigation to prepare this aircraft accident report.The pilot had been practicing touch-and-go landings.  On his final landing, the airplane swerved to the right and the right wing struck the ground, bending the spar.  The airplane then departed the runway.  According to the FAA airworthiness inspector who examined the airplane, the right brake caliper assembly showed "severely worn shoes with uneven wear."  The inspector surmised that when the pilot applied the brakes,  the uneven brake shoe wear "caused the caliper pins to engage misaligned, contacting the rotor, locking and shearing the caliper assembly."'

# %% [markdown]
# The first sentence from most of these is either a boilerplate intro or information that is otherwise provided in the metadata

# %%
# Let's delete the first sentence from each narrative 
# A function that deletes the first sentence
def remove_first_sentence(input):
    sentences = nltk.sent_tokenize(input)
    sentences = sentences[1:len(sentences)]
    sentences = ''.join(sentences)
    return sentences

# %%
# Create a new column 'ReducedNarrative' that we will create and fill using the narratives without their first sentence
# We will use this column moving forward to analyze and further clean the text
aviation_narratives['ReducedNarrative'] = aviation_narratives['Narrative'].apply(lambda input: remove_first_sentence(input))

# Are there any empty values here because there was only one sentence in the narrative?
print((aviation_narratives['ReducedNarrative'].values == '').sum())

# Remove empty narratives 
aviation_narratives = aviation_narratives[aviation_narratives.ReducedNarrative != '']
# Out:
# 0

# %%
# Get a frequency distribution of the most common words used in the currently uncleaned narrative 
unprocessed_freq = FreqDist(' '.join(aviation_narratives['ReducedNarrative'].str.lower()).split()).most_common(50)
print(unprocessed_freq)
# Out:
# [('the', 820457), ('and', 228278), ('to', 226538), ('of', 197999), ('was', 171811), ('a', 165246), ('that', 101091), ('pilot', 93030), ('airplane', 90149), ('in', 87369), ('he', 74279), ('on', 62321), ('at', 58557), ('with', 56690), ('were', 47159), ('engine', 45897), ('not', 44653), ('had', 43050), ('from', 40687), ('an', 39510), ('landing', 39387), ('fuel', 38892), ('for', 38402), ('left', 37511), ('flight', 33323), ('right', 31978), ('reported', 31397), ('about', 31023), ('no', 28711), ('aircraft', 26968), ('revealed', 25516), ('runway', 24340), ('during', 24224), ('it', 23919), ('acft', 23425), ('gear', 22881), ('by', 22750), ('or', 22738), ('stated', 22452), ('then', 22385), ('accident', 21597), ('&', 20799), ('feet', 20364), ('as', 19908), ('but', 19603), ('his', 19211), ('after', 19094), ('power', 19022), ('did', 18709), ('which', 17750)]

# %% [markdown]
# `There are a lot of uninformative words in here. Let's remove stopwords and lemmatize`

# %%
# Build a function that will lemmatize all of our words
lemmatizer = WordNetLemmatizer()

# First create a function that will get the type of word part of speech. 
# This will help us lemmatize by multiple POS. Lemmatizer will default to only lemmatizing nouns. 
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return None

def clean_text(input):
    # Set our stopwords and also include any punctuation. We will clean based on this variable. 
    stops = set(stopwords.words('english') + list(string.punctuation))
    # Only keep tokens that are not in stops and are alphanumeric text (I noticed that `` occurs as a token after trial and error)
    words = [word for word in pos_tag(word_tokenize(input.lower())) if word[0] not in stops and word[0].isalnum() == True]
    lemmatized_text = []
    for word, pos in words:
        wordnet_pos = get_wordnet_pos(pos) or wordnet.NOUN
        lemmatized_text.append(lemmatizer.lemmatize(word, pos = wordnet_pos))
    # do not join the text if the token is a digit
    return ' '.join((word for word in lemmatized_text if not word.isdigit()))

# %%
# Test it out on some sample text to make sure it behaves like we want it to. Run several times to evaluate performance.
# Generate a random number to sample from
random_row = random.randint(0, len(aviation_narratives))
print('This is the unprocessed text:')
print(aviation_narratives.at[random_row, 'Narrative'])
print('\n')
print('This is the processed text:')
print(clean_text(aviation_narratives.at[random_row, 'ReducedNarrative']))
# Out:
# This is the unprocessed text:
# NTSB investigators may not have traveled in support of this investigation and used data provided by various sources to prepare this aircraft accident report.During the takeoff roll, the flightcrew heard a "loud pop," and the airplane began to pull to the left. The pilot flying (PF) aborted the takeoff, and the airplane began to "fishtail" down the runway. The drag chute was activated by the pilot not flying (PNF); however, it appeared to be inoperative and the pilots were unable to stop the airplane on the runway. The airplane continued off the right side, impacted a runway light, and came to rest in the grass. Examination of the airplane revealed that both of the left main landing gear tires had blown, and the left main landing gear was separated from the airplane. Due to severe fragmentation of the tires, the origin of the tire failure could not be identified. Additionally, the strap of the drag chute had separated from the airplane, and was located in the vicinity of the blown tires. Airport personnel reported observing rocks and pieces of metal on the runway after the accident. Both tires were installed on the airplane approximately 3 weeks prior to the accident, and had accumulated 19 hours and 10 cycles since their installation. According to the airplane manufacturer, the drag chute should be deployed on landing at least once during each six-month interval. The drag chute should then be inspected and re-packed per the Maintenance Manual instructions. According to maintenance records, the drag chute was most recently re-packed during a routine inspection, three months prior to the accident, and the airplane had flown 59 hours since then. The drag chute had not been deployed prior to, or after the inspection.
#
#
# This is the processed text:
# pilot fly pf abort takeoff airplane begin fishtail drag chute activate pilot fly pnf however appear inoperative pilot unable stop airplane airplane continue right side impact runway light come rest airplane reveal left main landing gear tire blow left main landing gear separate severe fragmentation tire origin tire failure could strap drag chute separate airplane locate vicinity blown personnel report observe rock piece metal runway tire instal airplane approximately week prior accident accumulate hour cycle since airplane manufacturer drag chute deploy land least drag chute inspect per maintenance manual maintenance record drag chute recently routine inspection three month prior accident airplane fly hour since drag chute deploy prior inspection

# %%
# Run our function on the CleanNarrative text and overwrite the current column
# This takes a few minutes to run
aviation_narratives['CleanNarrative'] = aviation_narratives['ReducedNarrative'].apply(lambda input: clean_text(input))

# %%
aviation_narratives['CleanNarrative'].head()
# Out:
# 1    flight instructor private pilot instruction ai...
# 5    c90 sustain substantial damage falcon sustain ...
# 6    c90 sustain substantial damage falcon sustain ...
# 7    pilot two passenger receive minor helicopter s...
# 8    operate airplane provision code federal regula...
# Name: CleanNarrative, dtype: object

# %% [markdown]
# ## Task 3: Analysis of text frequency over time

# %%
# What is the count of entries by year?
aviation_narratives.groupby([aviation_narratives.EventDate.dt.year.rename('year')]).size()
# Out:
# year
# 1948.0       1
# 1962.0       1
# 1974.0       1
# 1977.0       1
# 1979.0       1
# 1981.0       1
# 1982.0    3489
# 1983.0    3458
# 1984.0    3372
# 1985.0    2985
# 1986.0    2760
# 1987.0    2728
# 1988.0    2658
# 1989.0    2475
# 1990.0    2416
# 1991.0    2398
# 1992.0    2268
# 1993.0    2240
# 1994.0    2240
# 1995.0    2293
# 1996.0    2175
# 1997.0    2136
# 1998.0    2209
# 1999.0    2191
# 2000.0    2210
# 2001.0    2044
# 2002.0    2012
# 2003.0    2078
# 2004.0    1941
# 2005.0    2024
# 2006.0    1836
# 2007.0    2008
# 2008.0    1925
# 2009.0    1799
# 2010.0    1812
# 2011.0    1874
# 2012.0    1840
# 2013.0    1526
# 2014.0    1486
# 2015.0     890
# dtype: int64

# %%
# What is the count by decade?
aviation_narratives.groupby(pd.cut(aviation_narratives.EventDate, pd.date_range('1940', '2020', freq='10YS'), right=False)).size()
# Out:
# EventDate
# [1940-01-01, 1950-01-01)        1
# [1950-01-01, 1960-01-01)        0
# [1960-01-01, 1970-01-01)        1
# [1970-01-01, 1980-01-01)        3
# [1980-01-01, 1990-01-01)    23926
# [1990-01-01, 2000-01-01)    22566
# [2000-01-01, 2010-01-01)    19877
# [2010-01-01, 2020-01-01)     9428
# dtype: int64

# %%
# Separate the data into sub data frames by decade. There are cleaner ways to do this, but this will suffice for the notebook.
# Create a year column
aviation_narratives['Year'] = pd.DatetimeIndex(aviation_narratives['EventDate']).year

# %%
# 1940s
narr_1940s = aviation_narratives.loc[(aviation_narratives['Year'] < 1950)]
FreqDist(' '.join(narr_1940s['CleanNarrative']).split()).most_common(5)
# Out:
# [('selway', 2), ('river', 2), ('wreckage', 2), ('two', 1), ('pilot', 1)]

# %%
# 1950s - There are no 
narr_1950s = aviation_narratives.loc[(aviation_narratives['Year'] >= 1950) & (aviation_narratives['Year'] < 1960)]
FreqDist(' '.join(narr_1950s['CleanNarrative']).split()).most_common(5)
# Out:
# []

# %%
# 1960s
narr_1960s = aviation_narratives.loc[(aviation_narratives['Year'] >= 1960) & (aviation_narratives['Year'] < 1970)]
FreqDist(' '.join(narr_1960s['CleanNarrative']).split()).most_common(5)
# Out:
# [('airplane', 4),
#  ('park', 2),
#  ('subsequently', 1),
#  ('collide', 1),
#  ('rise', 1)]

# %%
# 1970s
narr_1970s = aviation_narratives.loc[(aviation_narratives['Year'] >= 1970) & (aviation_narratives['Year'] < 1980)]
FreqDist(' '.join(narr_1970s['CleanNarrative']).split()).most_common(5)
# Out:
# [('pilot', 9), ('aircraft', 5), ('flight', 4), ('foot', 4), ('wreckage', 3)]

# %%
# 1980s
narr_1980s = aviation_narratives.loc[(aviation_narratives['Year'] >= 1980) & (aviation_narratives['Year'] < 1990)]
FreqDist(' '.join(narr_1980s['CleanNarrative']).split()).most_common(5)
# Out:
# [('acft', 22967),
#  ('plt', 14850),
#  ('pilot', 9789),
#  ('aircraft', 9074),
#  ('fuel', 8545)]

# %% [markdown]
# It looks like they start to use acronyms in the narratives - using acft, plt

# %%
# 1990s
narr_1990s = aviation_narratives.loc[(aviation_narratives['Year'] >= 1990) & (aviation_narratives['Year'] < 2000)]
FreqDist(' '.join(narr_1990s['CleanNarrative']).split()).most_common(5)
# Out:
# [('pilot', 32334),
#  ('airplane', 30251),
#  ('engine', 15438),
#  ('fuel', 12181),
#  ('aircraft', 11937)]

# %%
# 2000s
narr_2000s = aviation_narratives.loc[(aviation_narratives['Year'] >= 2000) & (aviation_narratives['Year'] < 2010)]
FreqDist(' '.join(narr_2000s['CleanNarrative']).split()).most_common(5)
# Out:
# [('airplane', 45769),
#  ('pilot', 41240),
#  ('engine', 19802),
#  ('flight', 16279),
#  ('report', 14813)]

# %%
# 2010s
narr_2010s = aviation_narratives.loc[(aviation_narratives['Year'] >= 2010) & (aviation_narratives['Year'] < 2020)]
FreqDist(' '.join(narr_2000s['CleanNarrative']).split()).most_common(5)
# Out:
# [('airplane', 45769),
#  ('pilot', 41240),
#  ('engine', 19802),
#  ('flight', 16279),
#  ('report', 14813)]

# %% [markdown]
# `Many of these words are still very generic. We can narrow down the words by frequency using the CountVectorizer`

# %% [markdown]
# ## Task 4: Topic clustering with LDA

# %%
# Create a count vectorizer so we can perform LDA. LDA needs raw frequency counts and then will weight terms for us. 
# We will set the max_df to something small to exclude words that are frequently used in the text
vectorizer = CountVectorizer(analyzer='word',
                             max_df=0.1, # ignore terms that have a frequency higher than 0.1 (trying to get more specific topics)
                             token_pattern='[a-zA-Z0-9]{3,}',  # num chars > 3
                             max_features=1000) # max number of unique words

data_vectorized = vectorizer.fit_transform(list(aviation_narratives['CleanNarrative']))

# %%
# Take a look at the word / frequency breakdown produced
vectorizer.vocabulary_
# Out:
# {'instructor': 447,
#  'private': 669,
#  'instruction': 446,
#  'sustain': 880,
#  'substantial': 867,
#  'register': 720,
#  'aviation': 81,
#  'operate': 589,
#  'west': 980,
#  'code': 167,
#  'federal': 324,
#  'regulation': 721,
#  'part': 613,
#  'meteorological': 527,
#  'prevail': 665,
#  'instrument': 448,
#  'rule': 762,
#  'ifr': 417,
#  'local': 494,
#  'originate': 597,
#  'perform': 626,
#  'last': 469,
#  'depart': 223,
#  'experience': 309,
#  'loss': 504,
#  'conduct': 182,
#  'forced': 350,
#  'field': 328,
#  'beyond': 103,
#  'departure': 224,
#  'rest': 735,
#  'retain': 739,
#  'minor': 532,
#  'airline': 33,
#  'transport': 929,
#  'two': 938,
#  'passenger': 618,
#  'provision': 680,
#  'subsequent': 865,
#  'preflight': 659,
#  'checklist': 156,
#  'complete': 175,
#  'park': 610,
#  'brake': 118,
#  'set': 790,
#  'handle': 386,
#  'pull': 682,
#  'wheel': 982,
#  'soon': 831,
#  'remove': 725,
#  'start': 849,
#  'across': 9,
#  'immediately': 420,
#  'apply': 57,
#  'however': 411,
#  'stop': 857,
#  'emergency': 280,
#  'system': 883,
#  'slow': 824,
#  'add': 14,
#  'ramp': 696,
#  'top': 914,
#  'parked': 611,
#  'beech': 96,
#  'near': 554,
#  'head': 389,
#  'collision': 170,
#  'receive': 708,
#  'helicopter': 395,
#  'substantially': 868,
#  'air': 30,
#  'south': 834,
#  'visual': 967,
#  'plan': 640,
#  'information': 431,
#  'problem': 671,
#  'take': 887,
#  'keep': 463,
#  'get': 369,
#  'rotor': 756,
#  'rpm': 759,
#  'another': 53,
#  'warn': 971,
#  'hard': 388,
#  'altitude': 48,
#  'slide': 819,
#  'skid': 816,
#  'break': 120,
#  'tail': 884,
#  'blade': 105,
#  'separate': 783,
#  'vertical': 959,
#  'stabilizer': 845,
#  'boom': 112,
#  'appear': 55,
#  'sole': 829,
#  'occupant': 581,
#  'injure': 435,
#  'personal': 630,
#  'destination': 231,
#  'earlier': 267,
#  'refuel': 717,
#  'full': 359,
#  'abort': 1,
#  'result': 738,
#  'taxi': 891,
#  'mechanic': 522,
#  'lock': 497,
#  'suggest': 874,
#  'wait': 969,
#  'normally': 565,
#  'align': 39,
#  'become': 95,
#  'airborne': 31,
#  'climb': 163,
#  'partial': 614,
#  'pitch': 638,
#  'pass': 617,
#  'locate': 495,
#  'cfi': 151,
#  'one': 586,
#  'owner': 606,
#  'telephone': 895,
#  'interview': 456,
#  'national': 552,
#  'safety': 766,
#  'board': 109,
#  'touchdown': 918,
#  'normal': 564,
#  'onto': 587,
#  'taxiway': 892,
#  'collapse': 168,
#  'without': 989,
#  'anomaly': 52,
#  'note': 571,
#  'preclude': 658,
#  'also': 43,
#  'company': 173,
#  'personnel': 631,
#  'incident': 424,
#  'record': 712,
#  'hour': 407,
#  'recover': 713,
#  'secure': 778,
#  'location': 496,
#  'own': 605,
#  'fatally': 321,
#  'file': 329,
#  'international': 454,
#  'witness': 990,
#  'final': 332,
#  'leg': 477,
#  'traffic': 924,
#  'pattern': 621,
#  'descend': 226,
#  'straight': 858,
#  'addition': 15,
#  'sound': 832,
#  'like': 485,
#  'throttle': 908,
#  'issue': 461,
#  'noise': 563,
#  'accord': 6,
#  'first': 335,
#  'fire': 333,
#  'parachute': 608,
#  'see': 779,
#  'hear': 391,
#  'wreckage': 993,
#  'minute': 533,
#  'extend': 310,
#  'several': 794,
#  'approximately': 59,
#  'tall': 888,
#  'attitude': 76,
#  'initial': 432,
#  'partially': 615,
#  'consume': 186,
#  'fuselage': 362,
#  'component': 177,
#  'vicinity': 963,
#  'continuity': 190,
#  'establish': 292,
#  'surface': 878,
#  'cockpit': 166,
#  'fracture': 355,
#  'remain': 723,
#  'attach': 73,
#  'exhibit': 305,
#  'cylinder': 210,
#  'propeller': 676,
#  'crankshaft': 200,
#  'tip': 912,
#  'lead': 473,
#  'edge': 270,
#  'display': 250,
#  'autopilot': 77,
#  'ntsb': 573,
#  'data': 212,
#  'day': 214,
#  'radar': 692,
#  'atc': 72,
#  'communication': 172,
#  'administration': 20,
#  'faa': 313,
#  'instruct': 445,
#  'maintain': 508,
#  'reach': 702,
#  'clear': 161,
#  'gps': 374,
#  'cross': 203,
#  'reverse': 742,
#  'course': 196,
#  'track': 923,
#  'along': 42,
#  'descent': 228,
#  'target': 890,
#  'mile': 529,
#  'arrival': 65,
#  'write': 994,
#  'statement': 850,
#  'light': 484,
#  'never': 559,
#  'illuminate': 419,
#  'visibility': 965,
#  'weather': 976,
#  'include': 425,
#  'knot': 464,
#  'overcast': 601,
#  'ceiling': 144,
#  'temperature': 897,
#  'dew': 237,
#  'point': 645,
#  'altimeter': 47,
#  'setting': 791,
#  'inch': 423,
#  'reduce': 715,
#  'fog': 347,
#  'lower': 506,
#  'elevation': 277,
#  'msl': 548,
#  'equip': 290,
#  'length': 478,
#  'minimum': 531,
#  'rwy': 764,
#  'procedure': 672,
#  'section': 777,
#  'night': 562,
#  'test': 899,
#  'site': 813,
#  'wooded': 991,
#  'path': 620,
#  'long': 500,
#  'terrain': 898,
#  'piece': 634,
#  'move': 545,
#  'recovery': 714,
#  'gallon': 365,
#  'examine': 299,
#  'hangar': 387,
#  'major': 510,
#  'flap': 339,
#  'mount': 542,
#  'consistent': 185,
#  'actuator': 13,
#  'outboard': 598,
#  'cable': 130,
#  'overload': 603,
#  'selector': 782,
#  'position': 648,
#  'third': 904,
#  'six': 815,
#  'similar': 809,
#  'number': 574,
#  'accessory': 4,
#  'rotate': 754,
#  'hand': 384,
#  'dual': 264,
#  'magneto': 507,
#  'contain': 188,
#  'tower': 922,
#  'spark': 838,
#  'carburetor': 139,
#  'intact': 450,
#  'float': 343,
#  'bowl': 116,
#  'exhaust': 304,
#  'pump': 683,
#  'drive': 261,
#  'destroy': 232,
#  'rat': 700,
#  'arrive': 66,
#  'oil': 584,
#  'back': 85,
#  'recall': 707,
#  'put': 687,
#  'cap': 136,
#  'saw': 768,
#  'proceed': 673,
#  'try': 933,
#  'exit': 307,
#  'base': 90,
#  'operator': 593,
#  'jet': 462,
#  'enter': 287,
#  'towards': 921,
#  'little': 491,
#  'later': 471,
#  'plane': 641,
#  'notice': 572,
#  'rock': 751,
#  'around': 62,
#  'crash': 201,
#  'block': 106,
#  'controller': 192,
#  'shortly': 801,
#  'line': 488,
#  'sudden': 871,
#  'catch': 142,
#  'sequence': 785,
#  'commercial': 171,
#  'radio': 693,
#  'contact': 187,
#  'subsequently': 866,
#  'advise': 22,
#  'publish': 681,
#  'miss': 534,
#  'switch': 882,
#  'frequency': 357,
#  'ask': 67,
#  'want': 970,
#  'able': 0,
#  'heading': 390,
#  'mean': 521,
#  'sea': 772,
#  'level': 480,
#  'drop': 262,
#  'rapidly': 699,
#  'east': 269,
#  'river': 749,
#  'debris': 215,
#  'percent': 625,
#  'seat': 775,
#  'spar': 837,
#  'empennage': 281,
#  'horizontal': 404,
#  'compartment': 174,
#  'lack': 466,
#  'elevator': 278,
#  'trim': 931,
#  'hold': 401,
#  'certificate': 148,
#  'recent': 709,
#  'medical': 523,
#  'total': 916,
#  'gusting': 381,
#  'thunderstorm': 911,
#  'rain': 694,
#  'seriously': 788,
#  'aerial': 24,
#  'application': 56,
#  'student': 864,
#  'injury': 436,
#  'serious': 787,
#  'past': 619,
#  'close': 164,
#  'observe': 578,
#  'station': 851,
#  'southwest': 836,
#  'northeast': 567,
#  'sky': 818,
#  'observation': 577,
#  'calm': 133,
#  'variable': 953,
#  'canyon': 135,
#  'cyclic': 209,
#  'movement': 546,
#  'inspector': 441,
#  'facility': 315,
#  'mountainous': 544,
#  'respond': 733,
#  'elect': 274,
#  'sign': 806,
#  'fatal': 320,
#  'glider': 372,
#  'detect': 233,
#  'upright': 948,
#  'intersection': 455,
#  'road': 750,
#  'cloud': 165,
#  'indicate': 427,
#  'toward': 920,
#  'estimate': 293,
#  'outside': 600,
#  'evidence': 297,
#  'inverted': 458,
#  'portion': 647,
#  'inboard': 422,
#  'still': 856,
#  'aileron': 29,
#  'aft': 26,
#  'rudder': 761,
#  'cabin': 129,
#  'almost': 41,
#  'completely': 176,
#  'scene': 770,
#  'cowling': 198,
#  'rear': 705,
#  'case': 141,
#  'upper': 947,
#  'plug': 644,
#  'valve': 952,
#  'verify': 958,
#  'compression': 178,
#  'except': 301,
#  'arm': 61,
#  'hose': 406,
#  'airframe': 32,
#  'manifold': 513,
#  'cover': 197,
#  'within': 988,
#  'speed': 839,
#  'rotation': 755,
#  'cut': 207,
#  'yoke': 998,
#  'associate': 70,
#  'angle': 50,
#  'structural': 861,
#  'panel': 607,
#  'cfr': 152,
#  'stand': 847,
#  'water': 973,
#  'directly': 243,
#  'front': 358,
#  'beach': 93,
#  'follow': 348,
#  'disappear': 245,
#  'loud': 505,
#  'previous': 667,
#  'large': 468,
#  'burn': 128,
#  'second': 776,
#  'standard': 848,
#  'morning': 540,
#  'brush': 125,
#  'postaccident': 652,
#  'motor': 541,
#  'series': 786,
#  'service': 789,
#  'north': 566,
#  'strip': 859,
#  'route': 758,
#  'city': 159,
#  'pick': 633,
#  'gain': 363,
#  'airspeed': 34,
#  'initiate': 434,
#  'release': 722,
#  'mountain': 543,
#  'spring': 843,
#  'member': 525,
#  'lake': 467,
#  'center': 146,
#  'signal': 807,
#  'search': 774,
#  'rise': 748,
#  'valley': 951,
#  'ridge': 746,
#  'identify': 415,
#  'green': 378,
#  'material': 518,
#  'transfer': 927,
#  'mark': 517,
#  'face': 314,
#  'surround': 879,
#  'slope': 823,
#  'original': 596,
#  'assembly': 68,
#  'indicator': 429,
#  'nautical': 553,
#  'layer': 472,
#  'density': 222,
#  'single': 811,
#  'review': 743,
#  'logbook': 499,
#  'accumulate': 7,
#  'model': 536,
#  'month': 539,
#  'spray': 842,
#  'autorotation': 78,
#  'way': 974,
#  'sever': 793,
#  'maneuver': 512,
#  'slight': 820,
#  'upon': 946,
#  'pole': 646,
#  'five': 337,
#  'purpose': 685,
#  'require': 731,
#  'use': 950,
#  'abruptly': 2,
#  'lever': 481,
#  'inadvertently': 421,
#  'idle': 416,
#  'effort': 272,
#  'unable': 940,
#  'pedal': 623,
#  'forward': 353,
#  'regain': 718,
#  'veer': 955,
#  'wire': 987,
#  'shoulder': 802,
#  'discrepancy': 249,
#  'inspection': 440,
#  'tank': 889,
#  'lean': 475,
#  'felt': 326,
#  'vibration': 962,
#  'heat': 392,
#  'mixture': 535,
#  'rich': 745,
#  'check': 155,
#  'performance': 627,
#  'fence': 327,
#  'select': 781,
#  'touch': 917,
#  'post': 651,
#  'scatter': 769,
#  'pressure': 664,
#  'cessna': 150,
#  'support': 877,
#  'downwind': 257,
#  'momentarily': 538,
#  'fall': 317,
#  'small': 825,
#  'action': 10,
#  'bank': 88,
#  'throughout': 909,
#  'solo': 830,
#  'acknowledge': 8,
#  'provide': 679,
#  'clearance': 162,
#  'response': 734,
#  'think': 903,
#  'fast': 319,
#  'need': 557,
#  'northwest': 568,
#  'canopy': 134,
#  'place': 639,
#  'confirm': 183,
#  'log': 498,
#  'force': 349,
#  'new': 560,
#  'obtain': 580,
#  'may': 520,
#  'return': 741,
#  'inform': 430,
#  'next': 561,
#  'transmission': 928,
#  'distance': 251,
#  'eventually': 296,
#  'cruise': 205,
#  'sputter': 844,
#  'restart': 736,
#  'date': 213,
#  'wide': 984,
#  'structure': 862,
#  'building': 126,
#  'four': 354,
#  'onboard': 585,
#  'high': 396,
#  'read': 703,
#  'bring': 123,
#  'limit': 487,
#  'declare': 217,
#  'discover': 248,
#  'look': 501,
#  'balloon': 87,
#  'rate': 701,
#  'per': 624,
#  'corn': 193,
#  'basket': 91,
#  'drag': 258,
#  'crew': 202,
#  'shut': 804,
#  'electrical': 276,
#  'request': 730,
#  'current': 206,
#  'short': 800,
#  'accelerate': 3,
#  'half': 383,
#  'descending': 227,
#  'view': 964,
#  'smoke': 826,
#  'behind': 97,
#  'centerline': 147,
#  'type': 939,
#  'black': 104,
#  'piston': 637,
#  'metal': 526,
#  'present': 663,
#  'maintenance': 509,
#  'manufacture': 515,
#  'annual': 51,
#  'correct': 194,
#  'far': 318,
#  'travel': 930,
#  'ditch': 252,
#  'tailwheel': 885,
#  'preimpact': 660,
#  'overrun': 604,
#  'circle': 157,
#  'successfully': 870,
#  'airstrip': 35,
#  'produce': 674,
#  'moderate': 537,
#  'effect': 271,
#  'dug': 266,
#  'slip': 822,
#  'firewall': 334,
#  'practice': 655,
#  'thereafter': 901,
#  'prepare': 661,
#  'dirt': 244,
#  'adjacent': 18,
#  'flip': 342,
#  'occur': 582,
#  'since': 810,
#  'fell': 325,
#  'describe': 229,
#  'airworthiness': 36,
#  'execute': 303,
#  'threshold': 907,
#  'away': 84,
#  'certified': 149,
#  'work': 992,
#  'stay': 852,
#  'battery': 92,
#  'list': 490,
#  'change': 153,
#  'call': 132,
#  'range': 697,
#  'representative': 729,
#  'intended': 452,
#  'alert': 38,
#  'direction': 241,
#  'due': 265,
#  'least': 476,
#  'stick': 855,
#  'invert': 457,
#  'tire': 913,
#  'determine': 235,
#  'operation': 591,
#  'cargo': 140,
#  'home': 403,
#  'house': 408,
#  'avoid': 82,
#  'retract': 740,
#  'sight': 805,
#  'stall': 846,
#  'broken': 124,
#  'significant': 808,
#  'bent': 101,
#  'postcrash': 653,
#  'push': 686,
#  'rod': 752,
#  'boost': 113,
#  'unit': 943,
#  'installation': 443,
#  'intend': 451,
#  'vfr': 960,
#  'three': 906,
#  'run': 763,
#  'parallel': 609,
#  'positive': 649,
#  'door': 255,
#  'fluid': 346,
#  'order': 595,
#  'sun': 875,
#  'civil': 160,
#  'visible': 966,
#  'uneventful': 942,
#  'fully': 360,
#  'difficulty': 239,
#  'bounce': 115,
#  'twice': 937,
#  'banner': 89,
#  'tow': 919,
#  'successful': 869,
#  'deploy': 225,
#  'flame': 338,
#  'late': 470,
#  'horn': 405,
#  'either': 273,
#  'unknown': 944,
#  'steep': 853,
#  'increase': 426,
#  'yard': 995,
#  'via': 961,
#  'training': 926,
#  'agl': 27,
#  'embankment': 279,
#  'lift': 482,
#  'fail': 316,
#  'nosewheel': 570,
#  'tell': 896,
#  'encounter': 283,
#  'grass': 375,
#  'attendant': 75,
#  'captain': 137,
#  'turbulence': 936,
#  'open': 588,
#  'neither': 558,
#  'bend': 100,
#  'strut': 863,
#  'skin': 817,
#  'wear': 975,
#  'manufacturer': 516,
#  'box': 117,
#  'ignition': 418,
#  'gascolator': 367,
#  'great': 377,
#  'advisory': 23,
#  'balance': 86,
#  'loose': 503,
#  'compressor': 179,
#  'turbine': 935,
#  'teardown': 894,
#  'glide': 371,
#  'initially': 433,
#  'slightly': 821,
#  'rescue': 732,
#  'bottom': 114,
#  'less': 479,
#  'strong': 860,
#  'amount': 49,
#  'cycle': 208,
#  'additional': 16,
#  'vehicle': 956,
#  'southeast': 835,
#  'believe': 98,
#  'extensive': 312,
#  'load': 493,
#  'truck': 932,
#  'trail': 925,
#  'zero': 999,
#  'rough': 757,
#  'hill': 398,
#  'berm': 102,
#  'cause': 143,
#  'direct': 240,
#  'sufficient': 873,
#  'severe': 795,
#  'concern': 180,
#  'might': 528,
#  'raise': 695,
#  'gust': 380,
#  'shift': 799,
#  'settle': 792,
#  'wingtip': 986,
#  'bearing': 94,
#  'reference': 716,
#  'nearby': 555,
#  'shear': 798,
#  'indication': 428,
#  'feather': 323,
#  'flat': 341,
#  'parking': 612,
#  'decide': 216,
#  'heavy': 393,
#  'suddenly': 872,
#  'torque': 915,
#  'week': 977,
#  'show': 803,
#  'deficiency': 219,
#  'inspect': 439,
#  'separation': 784,
#  'plate': 642,
#  'instal': 442,
#  'shaft': 796,
#  'filter': 331,
#  'operating': 590,
#  'advance': 21,
#  'proper': 677,
#  'expect': 308,
#  'maximum': 519,
#  'develop': 236,
#  'sink': 812,
#  'loop': 502,
#  'vector': 954,
#  'person': 629,
#  'drift': 260,
#  'purchase': 684,
#  'mph': 547,
#  'quit': 691,
#  'crosswind': 204,
#  'decrease': 218,
#  'nosed': 569,
#  'approve': 58,
#  'investigation': 459,
#  'well': 979,
#  'know': 465,
#  'ahead': 28,
#  'prevent': 666,
#  'unsuccessful': 945,
#  'divert': 254,
#  'shallow': 797,
#  'highway': 397,
#  'seem': 780,
#  'assist': 69,
#  'must': 551,
#  'function': 361,
#  'situation': 814,
#  'available': 80,
#  'input': 437,
#  'sample': 767,
#  'flare': 340,
#  'accomplish': 5,
#  'opposite': 594,
#  'therefore': 902,
#  'electric': 275,
#  'free': 356,
#  'realize': 704,
#  'enough': 286,
#  'height': 394,
#  'extension': 311,
#  'pas': 616,
#  'soft': 828,
#  'steer': 854,
#  'hit': 400,
#  'recently': 710,
#  'early': 268,
#  'gas': 366,
#  'leak': 474,
#  'multiple': 550,
#  'period': 628,
#  'operational': 592,
#  'warning': 972,
#  'preaccident': 656,
#  'hydraulic': 412,
#  'quarter': 690,
#  'instead': 444,
#  'nut': 575,
#  'bolt': 111,
#  'equipment': 291,
#  'hover': 410,
#  'fill': 330,
#  'collective': 169,
#  'arrest': 64,
#  'good': 373,
#  'gauge': 368,
#  'obstacle': 579,
#  'entire': 288,
#  'possible': 650,
#  'tube': 934,
#  'supply': 876,
#  'crack': 199,
#  'fitting': 336,
#  'cell': 145,
#  'yaw': 996,
#  'link': 489,
#  'give': 370,
#  'braking': 119,
#  'swerve': 881,
#  'reason': 706,
#  'engage': 285,
#  'contamination': 189,
#  'different': 238,
#  'downdraft': 256,
#  'though': 905,
#  'flow': 344,
#  'prop': 675,
#  'event': 295,
#  'rollout': 753,
#  'manual': 514,
#  'wet': 981,
#  'attachment': 74,
#  'pin': 635,
#  'exceed': 300,
#  'activate': 11,
#  'remember': 724,
#  'blow': 108,
#  'adequate': 17,
#  'spot': 841,
#  'hole': 402,
#  'reportedly': 728,
#  'drain': 259,
#  'restore': 737,
#  'spin': 840,
#  'repair': 726,
#  'replace': 727,
#  'dry': 263,
#  'belt': 99,
#  'actual': 12,
#  'demonstrate': 221,
#  'liftoff': 483,
#  'insufficient': 449,
#  'officer': 583,
#  'much': 549,
#  'bulletin': 127,
#  'ice': 413,
#  'chart': 154,
#  'icing': 414,
#  'likely': 486,
#  'quantity': 689,
#  'seal': 773,
#  'previously': 668,
#  'inside': 438,
#  'connect': 184,
#  'precautionary': 657,
#  'dive': 253,
#  'tailwind': 886,
#  'rapid': 698,
#  'adjust': 19,
#  'visually': 968,
#  'design': 230,
#  'exam': 298,
#  'nearly': 556,
#  'tear': 893,
#  'form': 352,
#  'vent': 957,
#  'entry': 289,
#  'testing': 900,
#  'assume': 71,
#  'directional': 242,
#  'presence': 662,
#  'corrosion': 195,
#  'screen': 771,
#  'housing': 409,
#  'allow': 40,
#  'internal': 453,
#  'gross': 379,
#  'weight': 978,
#  'history': 399,
#  'piper': 636,
#  'pic': 632,
#  'manager': 511,
#  'empty': 282,
#  'alcohol': 37,
#  'thrust': 910,
#  'auxiliary': 79,
#  'regard': 719,
#  'safe': 765,
#  'brief': 121,
#  'forecast': 351,
#  'conducive': 181,
#  'involve': 460,
#  'disclose': 246,
#  'uncontrolled': 941,
#  'disconnect': 247,
#  'although': 46,
#  'gravel': 376,
#  'ring': 747,
#  'handbook': 385,
#  'affect': 25,
#  'dark': 211,
#  'year': 997,
#  'circuit': 158,
#  'exist': 306,
#  'recommend': 711,
#  'overhaul': 602,
#  'outer': 599,
#  'gusty': 382,
#  'whether': 983,
#  'pound': 654,
#  'contribute': 191,
#  'snow': 827,
#  'properly': 678,
#  'excessive': 302,
#  'source': 833,
#  'alternate': 45,
#  'calculate': 131,
#  'windshield': 985,
#  'briefing': 122,
#  'probability': 670,
#  'even': 294,
#  'deteriorate': 234,
#  'aware': 83,
#  'obscure': 576,
#  'usable': 949,
#  'blood': 107,
#  'gal': 364,
#  'eng': 284,
#  'min': 530,
#  'medication': 524,
#  'fatigue': 322,
#  'boeing': 110,
#  'alt': 44,
#  'pax': 622,
#  'deg': 220,
#  'carb': 138,
#  'arpt': 63,
#  'pwr': 688,
#  'flt': 345,
#  'lndg': 492,
#  'plts': 643,
#  'apch': 54,
#  'aprx': 60,
#  'rgt': 744,
#  'rprtd': 760}

# %%
# Find the best number of topics and learning decay to perform LDA
# I commented this out because it took several hours to run

# Define Search Parameters
#In the interest of avoiding long compute time, let's set 12 as the max amount of clusters since more clusters will mean more homogeneity.
# Set a min of 2 clusters since 1 cluster is meaningless.
#search_params = {'n_components': range(2,12)}

# Initialize the model
#lda = LatentDirichletAllocation()

# Initialize a grid search class
#model = GridSearchCV(lda, param_grid=search_params)

# Perform a grid search on our search parameters
#model.fit(data_vectorized)

# Best model
#best_lda_model = model.best_estimator_

# Model parameters
#print("Best Model's Params: ", model.best_params_) # 5 components (aka topics) was the best number

# %%
# Build the LDA Model
lda_model = LatentDirichletAllocation(n_components=5, # Number of topics
                                      learning_method='online', # This will improve speed vs batch   
                                      random_state=100, # Set a random state for output consistency 
                                      n_jobs = -1, # Use all available CPUs
                                     )

lda_output = lda_model.fit_transform(data_vectorized)

# %%
# I'd like to see the top keywords for each topic
# A function that will generate the top n keywords for each topic
def show_topics(vectorizer, model, n_words=20):
    keywords = np.array(vectorizer.get_feature_names_out())
    topic_keywords = []
    for topic_weights in model.components_:
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        topic_keywords.append(keywords.take(top_keyword_locs))
    return topic_keywords

# What are the top 15 words for each topic cluster?
topic_keywords = show_topics(vectorizer=vectorizer, model=lda_model, n_words=15)

# %%
# Create a topic - keyword dataframe
df_topic_keywords = pd.DataFrame(topic_keywords)
df_topic_keywords.columns = ['Word '+str(i) for i in range(df_topic_keywords.shape[1])]
df_topic_keywords
# Out:
#        Word 0      Word 1      Word 2     Word 3     Word 4 Word 5    Word 6  \
# 0     witness         rwy        mile  passenger    weather    flt     crash
# 1        tank         run  carburetor       loss     forced  field     water
# 2         eng  inspection         oil       fail  propeller   fire  separate
# 3  helicopter     student       brake      touch      apply   tail      knot
#
#     Word 7      Word 8       Word 9   Word 10   Word 11    Word 12  Word 13  \
# 0  observe    wreckage      contact    cessna      near      level  receive
# 1     full      gallon     position    system     climb   altitude     flap
# 2    blade    cylinder  maintenance  assembly  evidence   fracture     hour
# 3    rotor  instructor         stop      full      hard  touchdown     veer
#
#     Word 14
# 0  altitude
# 1  selector
# 2    result
# 3   contact

# %% [markdown]
# The first topic is kind of ambiguous. It contains weather, but it also contains 'rwy' or runway. It could be a weather related crash while trying to land, but it could also be talking about crashes in general (not helpful)
#
# The second topic seems to be focused on fuel issues - tank, carburetor, loss, gallon - so this one looks better.
#
# The third topic looks to be focused on mechanical issues - engine, oil, fail, propeller, fire - this topic is strong.
#
# The fourth topic may be helicopter specific - helicopter and rotor appear - but it also looks to include student pilots with words like instructor and student. Perhaps it's student helicopter pilots?
#
# The fifth topic seems to talk about steering and landing the plane - apply, touch, brake, stop, flap, touchdown - this topic appears to be pretty strong as well.

# %%
# Assign unique names to the topics based on the words present
topics = ['Topic 1: Weather / misc crash', 'Topic 2: Fuel Issue', 'Topic 3: Engine / Mechanical Failure', 'Topic 4: Helicopter / student', 'Topic 5: Steering or Landing']
df_topic_keywords.index = [topics]
df_topic_keywords
# Out:
#                                   Word 0      Word 1      Word 2      Word 3  \
# Topic 1: Weather / misc          witness         rwy        mile     weather
# Topic 2: Fuel Issue                 tank         run  carburetor      forced
# Topic 3: Mechanical Failure          eng  inspection         oil        fail
# Topic 4: Helicopter           helicopter   passenger       rotor  instructor
# Topic 5: Steering or Landing       apply       touch       brake        full
#
#                                  Word 4   Word 5    Word 6    Word 7  \
# Topic 1: Weather / misc             flt  observe     crash  altitude
# Topic 2: Fuel Issue                loss    field    cessna    gallon
# Topic 3: Mechanical Failure   propeller     fire  cylinder    system
# Topic 4: Helicopter             student      cfi      tail    glider
# Topic 5: Steering or Landing       knot     stop      flap      back
#
#                                  Word 8       Word 9   Word 10   Word 11  \
# Topic 1: Weather / misc           level     wreckage     climb   descend
# Topic 2: Fuel Issue                hour     selector    switch      pump
# Topic 3: Mechanical Failure    separate  maintenance  assembly  fracture
# Topic 4: Helicopter                seat      operate   federal    injury
# Topic 5: Steering or Landing  touchdown        wheel      veer    rudder
#
#                                Word 12   Word 13         Word 14
# Topic 1: Weather / misc        contact       saw          locate
# Topic 2: Fuel Issue              water      full        position
# Topic 3: Mechanical Failure   evidence    result          number
# Topic 4: Helicopter            receive  aviation  meteorological
# Topic 5: Steering or Landing      rest       hit            hard

# %% [markdown]
# This is helpful but let's visualize what's going on with our topics. The ideal cluster outcome will be decently sized clusters that are heterogeneous in space. There's a really cool package called pyLDAvis that will visualize our model and allow us to interact with the clusters to see their terms.

# %% [markdown]
# ## Task 5: Create a chart that you feel conveys one important relationship in the data

# %%
import pyLDAvis.sklearn

# From experience this package uses some deprecated functions that throw warnings so we will ignore those warnings below.
import warnings
warnings.filterwarnings('ignore')

# Setting up pyLDAvis
pyLDAvis.enable_notebook()

# This takes our lda model, the word count vectorized 'bag of words', and the vectorizer model,
# reduces the data down to two dimensions for display, and provides a nifty term frequency chart for each cluster. 
# We will use tsne for dimension reduction. 
pyLDAvis.sklearn.prepare(lda_model, data_vectorized, vectorizer, mds='tsne', sort_topics=False)
# Out:
# PreparedData(topic_coordinates=                x           y  topics  cluster       Freq
# topic
# 0      150.222153  -72.269554       1        1  28.204314
# 1       51.163364 -159.968018       2        1  16.701029
# 2      -73.144554   21.523815       3        1  20.212031
# 3      -66.410133 -110.606438       4        1  10.432823
# 4       54.417324   12.443444       5        1  24.449803, topic_info=            Term          Freq         Total Category  logprob  loglift
# 395   helicopter  17134.000000  17134.000000  Default  30.0000  30.0000
# 889         tank  13303.000000  13303.000000  Default  29.0000  29.0000
# 618    passenger  10152.000000  10152.000000  Default  28.0000  28.0000
# 756        rotor   7753.000000   7753.000000  Default  27.0000  27.0000
# 864      student   9451.000000   9451.000000  Default  26.0000  26.0000
# ..           ...           ...           ...      ...      ...      ...
# 940       unable   3293.438861   6116.761694   Topic5  -5.0009   0.7894
# 187      contact   3798.098048   9366.496171   Topic5  -4.8583   0.5059
# 396         high   3419.452171   7351.650211   Topic5  -4.9634   0.6431
# 867  substantial   2865.256229   4632.763721   Topic5  -5.1402   0.9281
# 738       result   2891.922068   7506.453076   Topic5  -5.1309   0.4547
#
# [316 rows x 6 columns], token_table=      Topic      Freq            Term
# term
# 1         5  0.999619           abort
# 14        1  0.000262             add
# 14        2  0.194872             add
# 14        5  0.804665             add
# 20        1  0.000637  administration
# ...     ...       ...             ...
# 990       3  0.003544         witness
# 993       1  0.745397        wreckage
# 993       2  0.113607        wreckage
# 993       3  0.092415        wreckage
# 993       4  0.048466        wreckage
#
# [602 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 2, 3, 4, 5])

# %% [markdown]
# My opinion on these clusters has changed a bit based on the term frequency results for each cluster shown in the visualization.
#
# Topic 1 contains almost all of the 'witness' terms, all 'rwy' terms and all 'weather' terms. This implies this topic may contain the most fatal crashes since it has to do with witness accounts, not first hand accounts. These crashes are likely on runways and weather related. Terms like crash and wreckage support this idea of fatal or serious accidents being captured by this cluster.
#
# Topic 2 pretty much aligns with my original topic name 'Fuel Issue.' It contains the full corpus of tank and carburetor. Words like forced and loss imply losing fuel or having a fuel system related malfunction and being forced to land.
#
# Topic 3 is similar to Topic 2 in that it aligns well with my original topic name 'Engine / Mechanical Failure.' It contains the full corpus of eng, oil, and cylinder, and words like fail, fire, and propeller support this topic narrative of the engine having serious issues leading to loss of power.
#
# Topic 4 is our smallest cluster but it contains all of the helicopter and instructor word entries. This cluster is obviously related to helicopter incidents - rotor is also here - but this topic looks to be lumping incidents related to pilots that are learning in with helicopter incidents. The prevalence of the acronym cfi (certified flight instructor) and the high frequency of student supports this idea.
#
# Topic 5 largely supports my original name 'Steering or Landing' with its mix of a lot of flight steering related terms. I will also say that my gut feeling is that this topic would not have many fatal crashes given most of the words have to do with in-flight steering issues (meaning it would be a first hand account of the pilot's experience) and the word touchdown is heavily represented, implying the aircraft made it to the ground at least mostly intact. I would assume this topic would capture a lot of minor incidents.
#
# These topics do have a crude narrative based on term frequency within the selected topic relative to the overall term frequency in the corpus. More advanced techniques like bert may give us better clusters (but admittedly I have never used bert and it's out of my reach for something like this). I did pursue using tfidf, calculating cosine similarity, and using KMeans to cluster, but I couldn't overcome the hurdle of my computer giving up on the cosine similarity math due to the huge size of our matrix.
#
# This exercise could be done better but I feel good about my results given the time constraints!
